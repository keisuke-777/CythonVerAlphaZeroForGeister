# %%
# !git clone https://github.com/keisuke-777/AlphaZeroForMiniGeister.git
# Out:
# Cloning into 'AlphaZeroForMiniGeister'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 155 (delta 5), reused 13 (delta 4), pack-reused 135
# Receiving objects: 100% (155/155), 69.95 MiB | 851.00 KiB/s, done.
# Resolving deltas: 100% (74/74), done.

# %%
# %load_ext Cython
# Out:
#   File "<ipython-input-10-078de8d6b9da>", line 3
#     def cyfib(int n):
#                   ^
# SyntaxError: invalid syntax

# %%
# %%timeit
# !python game.py
# Out:
# Traceback (most recent call last):
#   File "game.py", line 229, in <module>
#     from pv_mcts import predict
#   File "/Users/keisuke_main/研究室/研究全般/Geister/AlphaZeroForGeister/pv_mcts.py", line 6, in <module>
#     from game import State
#   File "/Users/keisuke_main/研究室/研究全般/Geister/AlphaZeroForGeister/game.py", line 229, in <module>
#     from pv_mcts import predict
# ImportError: cannot import name 'predict'
# Traceback (most recent call last):
#   File "game.py", line 229, in <module>
#     from pv_mcts import predict
#   File "/Users/keisuke_main/研究室/研究全般/Geister/AlphaZeroForGeister/pv_mcts.py", line 6, in <module>
#     from game import State
#   File "/Users/keisuke_main/研究室/研究全般/Geister/AlphaZeroForGeister/game.py", line 229, in <module>
#     from pv_mcts import predict
# ImportError: cannot import name 'predict'
# Traceback (most recent call last):
#   File "game.py", line 229, in <module>
#     from pv_mcts import predict
# ...
